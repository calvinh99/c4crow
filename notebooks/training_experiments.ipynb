# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from c4crow.rl_train import *

# %% [markdown]
# So I've already trained 40000 games between a policy net and a random player. With coin flip the policy net goes first or second with a 50-50 chance.

# %%
plot_eval_history("../rl_checkpoints/DQN2_policy_net_2024-07-08_08-03-36/eval_history_40000.csv")

# %% [markdown]
# Doesn't seem to have much changes. I think it's a scale problem. We need to replicate AlphaZero and run games in massively parallel tensor ops while doing MCE at the same time.
